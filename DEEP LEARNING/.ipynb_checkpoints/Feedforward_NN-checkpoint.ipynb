# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
crop = pd.read_csv("crop_yield_data(in).csv")

# %%
crop
# Out:
#    temperature  humidity  rainfall  soil_quality  fertilizer_used  crop_yield
# 0           25        60        50             7              200        2000
# 1           28        65        60             6              220        2200
# 2           24        58        40             8              180        1800
# 3           26        62        55             7              210        2100
# 4           22        59        45             6              190        1900
# 5           30        70        70             7              250        2500
# 6           23        64        65             6              240        2300
# 7           27        63        50             8              200        2200
# 8           29        68        75             7              230        2400
# 9           25        60        55             6              210        2100

# %%
crop.isna().sum()
# Out:
# temperature        0
# humidity           0
# rainfall           0
# soil_quality       0
# fertilizer_used    0
# crop_yield         0
# dtype: int64

# %%
X = crop.drop('crop_yield', axis = 1) #Features
y = crop['crop_yield'] #Target

# %%
X
# Out:
#    temperature  humidity  rainfall  soil_quality  fertilizer_used
# 0           25        60        50             7              200
# 1           28        65        60             6              220
# 2           24        58        40             8              180
# 3           26        62        55             7              210
# 4           22        59        45             6              190
# 5           30        70        70             7              250
# 6           23        64        65             6              240
# 7           27        63        50             8              200
# 8           29        68        75             7              230
# 9           25        60        55             6              210

# %%
y
# Out:
# 0    2000
# 1    2200
# 2    1800
# 3    2100
# 4    1900
# 5    2500
# 6    2300
# 7    2200
# 8    2400
# 9    2100
# Name: crop_yield, dtype: int64

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

#scaler_y = StandardScaler()
y_scaled = scaler.fit_transform(y.values.reshape(-1, 1))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.2, random_state = 42)

# %%
crop_model = Sequential()

# %%
X_train.shape
# Out:
# (8, 5)

# %%
crop_model.add(Dense(64, input_dim = X_train.shape[1], activation = 'relu'))
crop_model.add(Dense(32, activation = 'relu'))
crop_model.add(Dense(1, activation = 'linear'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
crop_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,497 (9.75 KB)
#  Trainable params: 2,497 (9.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
crop_model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['mae'])

# %%
crop_model.fit(X_train, y_train, epochs = 50, batch_size = 4)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.3012 - mae: 0.4530
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3579 - mae: 0.4815
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1950 - mae: 0.3838
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1881 - mae: 0.3414
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1534 - mae: 0.3288
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0841 - mae: 0.2485
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0527 - mae: 0.1810
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0271 - mae: 0.1229
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0319 - mae: 0.1447
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0207 - mae: 0.1189
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0172 - mae: 0.1034
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0181 - mae: 0.1091
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0190 - mae: 0.1063
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0151 - mae: 0.0969
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0184 - mae: 0.1078
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0131 - mae: 0.0925
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0152 - mae: 0.1034
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0114 - mae: 0.0838
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0086 - mae: 0.0744
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0067 - mae: 0.0694
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0052 - mae: 0.0617
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0048 - mae: 0.0605
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0040 - mae: 0.0536
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0525
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0037 - mae: 0.0487
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0058 - mae: 0.0572
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0035 - mae: 0.0468
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0033 - mae: 0.0463
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0050 - mae: 0.0546
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0027 - mae: 0.0409
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0471
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0025 - mae: 0.0411
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0452
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0036 - mae: 0.0516
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0032 - mae: 0.0488
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0025 - mae: 0.0419
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0025 - mae: 0.0432
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0021 - mae: 0.0378
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0026 - mae: 0.0428
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0022 - mae: 0.0393
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022 - mae: 0.0387
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0018 - mae: 0.0364
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0022 - mae: 0.0390
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022 - mae: 0.0404
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0015 - mae: 0.0324
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0019 - mae: 0.0359
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0014 - mae: 0.0308
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0014 - mae: 0.0303
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0014 - mae: 0.0313
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0016 - mae: 0.0318

# %%
loss = crop_model.evaluate(X_test, y_test)
print(loss)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 0.0029 - mae: 0.0482
# [0.0029037264175713062, 0.04821944236755371]

# %%
from sklearn.metrics import r2_score
# Predict (scaled)
y_pred_scaled = crop_model.predict(X_test)
print(f"Scaled output: {y_pred_scaled}")
# Inverse transform predictions
y_pred = scaler.inverse_transform(y_pred_scaled)
print(f"Normal Output: {y_pred}")
y_actual = scaler.inverse_transform(y_test)
print(f"Actual output: {y_pred_scaled}")

# R² score
r2 = r2_score(y_actual, y_pred)
print(f"R² Score: {r2:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Scaled output: [[0.92941666]
#  [0.5955937 ]]
# Normal Output: [[2450.5916]
#  [2216.9155]]
# Actual output: [[0.92941666]
#  [0.5955937 ]]
# R² Score: 0.86

# %%
y_pred
# Out:
# array([[2450.5916],
#        [2216.9155]], dtype=float32)

# %%
y_actual
# Out:
# array([[2400.],
#        [2200.]])
