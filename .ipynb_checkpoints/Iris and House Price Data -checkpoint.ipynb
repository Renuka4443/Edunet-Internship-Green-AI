# %%
import pandas as pd

# %%
#DataFrame from CSV
housing_data=pd.read_csv("HousePrices.csv")
housing_data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#DataFrame from CSV
iris_df=pd.read_excel("Iris.xlsx")
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_df.shape
# Out:
# (150, 5)

# %%
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris_df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris_df['species'].nunique()
# Out:
# 3

# %%
iris_df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
iris_df[['sepal_width','petal_length','petal_width']]
# Out:
#      sepal_width  petal_length  petal_width
# 0            3.5           1.4          0.2
# 1            3.0           1.4          0.2
# 2            3.2           1.3          0.2
# 3            3.1           1.5          0.2
# 4            3.6           1.4          0.2
# ..           ...           ...          ...
# 145          3.0           5.2          2.3
# 146          2.5           5.0          1.9
# 147          3.0           5.2          2.0
# 148          3.4           5.4          2.3
# 149          3.0           5.1          1.8
#
# [150 rows x 3 columns]

# %%
#access specific row
iris_df.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
iris_df[iris_df["sepal_length"]>5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [118 rows x 5 columns]

# %%
iris_df.at[2,'species']
# Out:
# 'setosa'

# %%
iris_df.iat[1,2]
# Out:
# np.float64(1.4)

# %%
iris_df.loc[10,'species']
# Out:
# 'setosa'

# %%
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris_df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_df.drop('species',axis=1)    #0 for row,1 for column
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_df.drop('species',axis=1,inplace=True)

# %%
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
housing_data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
# !pip install datetime
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from datetime import datetime,timedelta

# %%
today=datetime.now()
print(f"Now the time is:{today}")
# Out:
# Now the time is:2025-06-10 16:02:38.019179

# %%
next_date=today+timedelta(days=6)
print(next_date)
# Out:
# 2025-06-16 16:02:38.019179

# %%
#Creating the date range
date_range=pd.date_range(start="2025-01-01",end="2025-10-01",freq="MS")
date_range
# Out:
# DatetimeIndex(['2025-01-01', '2025-02-01', '2025-03-01', '2025-04-01',
#                '2025-05-01', '2025-06-01', '2025-07-01', '2025-08-01',
#                '2025-09-01', '2025-10-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
#extracting the components of dates
df=pd.DataFrame(date_range)
df
# Out:
#            0
# 0 2025-01-01
# 1 2025-02-01
# 2 2025-03-01
# 3 2025-04-01
# 4 2025-05-01
# 5 2025-06-01
# 6 2025-07-01
# 7 2025-08-01
# 8 2025-09-01
# 9 2025-10-01

# %%
df['Date'] = df[0]

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df
# Out:
#            0       Date
# 0 2025-01-01 2025-01-01
# 1 2025-02-01 2025-02-01
# 2 2025-03-01 2025-03-01
# 3 2025-04-01 2025-04-01
# 4 2025-05-01 2025-05-01
# 5 2025-06-01 2025-06-01
# 6 2025-07-01 2025-07-01
# 7 2025-08-01 2025-08-01
# 8 2025-09-01 2025-09-01
# 9 2025-10-01 2025-10-01

# %%
df.drop(0,axis=1,inplace=True)

# %%
df
# Out:
#         Date
# 1 2025-02-01
# 2 2025-03-01
# 3 2025-04-01
# 4 2025-05-01
# 5 2025-06-01
# 6 2025-07-01
# 7 2025-08-01
# 8 2025-09-01
# 9 2025-10-01

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df["Day"]=df["Date"].dt.day
df["Month"]=df["Date"].dt.month
df["Year"]=df["Date"].dt.year

# %%
df
# Out:
#         Date  Day  Month  Year
# 1 2025-02-01    1      2  2025
# 2 2025-03-01    1      3  2025
# 3 2025-04-01    1      4  2025
# 4 2025-05-01    1      5  2025
# 5 2025-06-01    1      6  2025
# 6 2025-07-01    1      7  2025
# 7 2025-08-01    1      8  2025
# 8 2025-09-01    1      9  2025
# 9 2025-10-01    1     10  2025

# %%
df["Is_Weekend"] = df["Date"].dt.dayofweek >= 5
df
# Out:
#         Date  Day  Month  Year  Is_Weekend
# 1 2025-02-01    1      2  2025        True
# 2 2025-03-01    1      3  2025        True
# 3 2025-04-01    1      4  2025       False
# 4 2025-05-01    1      5  2025       False
# 5 2025-06-01    1      6  2025        True
# 6 2025-07-01    1      7  2025       False
# 7 2025-08-01    1      8  2025       False
# 8 2025-09-01    1      9  2025       False
# 9 2025-10-01    1     10  2025       False
