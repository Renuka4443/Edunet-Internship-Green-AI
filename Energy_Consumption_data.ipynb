# %%
import pandas as pd

# %%
df=pd.read_csv("energy_consumption.csv")
df
# Out:
#    Energy_Source  Energy_Consumption(MWh)  Cost(Million$)
# 0     Geothermal                   2363.0           234.0
# 1        Biomass                   1241.0           147.0
# 2     Hydropower                      NaN           367.0
# 3        Biomass                   3041.0           392.0
# 4        Biomass                   3061.0           234.0
# 5           Wind                   2363.0             NaN
# 6     Hydropower                   3041.0           234.0
# 7     Hydropower                   3061.0           427.0
# 8     Hydropower                   3612.0           234.0
# 9        Biomass                   3612.0             NaN
# 10    Geothermal                   2390.0           427.0
# 11    Hydropower                   3041.0           315.0
# 12       Nuclear                   3612.0           132.0
# 13       Biomass                   3061.0           132.0
# 14          Wind                   2390.0           392.0
# ...

# %%
df.head()
# Out:
#   Energy_Source  Energy_Consumption(MWh)  Cost(Million$)
# 0    Geothermal                   2363.0           234.0
# 1       Biomass                   1241.0           147.0
# 2    Hydropower                   2799.4           367.0
# 3       Biomass                   3041.0           392.0
# 4       Biomass                   3061.0           234.0

# %%
df.tail()
# Out:
#    Energy_Source  Energy_Consumption(MWh)  Cost(Million$)
# 45         Solar                   3824.0           161.0
# 46          Wind                   2390.0           392.0
# 47    Geothermal                   3945.0           161.0
# 48         Solar                   2390.0           300.0
# 49    Geothermal                   3139.0           161.0

# %%
df.shape
# Out:
# (50, 3)

# %%
df.describe()
# Out:
#        Energy_Consumption(MWh)  Cost(Million$)
# count                 45.00000       45.000000
# mean                2799.40000      265.244444
# std                  722.61971      106.250809
# min                 1241.00000      127.000000
# 25%                 2363.00000      161.000000
# 50%                 3041.00000      300.000000
# 75%                 3139.00000      367.000000
# max                 3945.00000      427.000000

# %%
df.isna().sum()
# Out:
# Energy_Source              0
# Energy_Consumption(MWh)    5
# Cost(Million$)             5
# dtype: int64

# %%
df['Energy_Consumption(MWh)'].fillna(df['Energy_Consumption(MWh)'].mean(),inplace=True)
# Out:
# C:\Users\RENUKA\AppData\Local\Temp\ipykernel_21108\2276603720.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Energy_Consumption(MWh)'].fillna(df['Energy_Consumption(MWh)'].mean(),inplace=True)

# %%
df['Cost(Million$)'].fillna(df['Cost(Million$)'].mean(),inplace=True)
# Out:
# C:\Users\RENUKA\AppData\Local\Temp\ipykernel_21108\3351113968.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cost(Million$)'].fillna(df['Cost(Million$)'].mean(),inplace=True)

# %%
df
# Out:
#    Energy_Source  Energy_Consumption(MWh)  Cost(Million$)
# 0     Geothermal                   2363.0      234.000000
# 1        Biomass                   1241.0      147.000000
# 2     Hydropower                   2799.4      367.000000
# 3        Biomass                   3041.0      392.000000
# 4        Biomass                   3061.0      234.000000
# 5           Wind                   2363.0      265.244444
# 6     Hydropower                   3041.0      234.000000
# 7     Hydropower                   3061.0      427.000000
# 8     Hydropower                   3612.0      234.000000
# 9        Biomass                   3612.0      265.244444
# 10    Geothermal                   2390.0      427.000000
# 11    Hydropower                   3041.0      315.000000
# 12       Nuclear                   3612.0      132.000000
# 13       Biomass                   3061.0      132.000000
# 14          Wind                   2390.0      392.000000
# ...

# %%
df.fillna(method="ffill")
# Out:
# C:\Users\RENUKA\AppData\Local\Temp\ipykernel_21108\3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#    Energy_Source  Energy_Consumption(MWh)  Cost(Million$)
# 0     Geothermal                   2363.0      234.000000
# 1        Biomass                   1241.0      147.000000
# 2     Hydropower                   2799.4      367.000000
# 3        Biomass                   3041.0      392.000000
# 4        Biomass                   3061.0      234.000000
# 5           Wind                   2363.0      265.244444
# 6     Hydropower                   3041.0      234.000000
# 7     Hydropower                   3061.0      427.000000
# 8     Hydropower                   3612.0      234.000000
# 9        Biomass                   3612.0      265.244444
# 10    Geothermal                   2390.0      427.000000
# ...

# %%
df.isna().sum()
# Out:
# Energy_Source              0
# Energy_Consumption(MWh)    0
# Cost(Million$)             0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_scale=MinMaxScaler()
df[["Energy_Consumption(MWh)","Cost(Million$)"]]=min_scale.fit_transform(df[["Energy_Consumption(MWh)","Cost(Million$)"]])

# %%
df
# Out:
#    Energy_Source  Energy_Consumption(MWh)  Cost(Million$)
# 0     Geothermal                 0.414941        0.356667
# 1        Biomass                 0.000000        0.066667
# 2     Hydropower                 0.576331        0.800000
# 3        Biomass                 0.665680        0.883333
# 4        Biomass                 0.673077        0.356667
# 5           Wind                 0.414941        0.460815
# 6     Hydropower                 0.665680        0.356667
# 7     Hydropower                 0.673077        1.000000
# 8     Hydropower                 0.876849        0.356667
# 9        Biomass                 0.876849        0.460815
# 10    Geothermal                 0.424926        1.000000
# 11    Hydropower                 0.665680        0.626667
# 12       Nuclear                 0.876849        0.016667
# 13       Biomass                 0.673077        0.016667
# 14          Wind                 0.424926        0.883333
# ...

# %%
pd.get_dummies(df,columns=["Energy_Source"])
# Out:
#     Energy_Consumption(MWh)  Cost(Million$)  Energy_Source_Biomass  \
# 0                  0.414941        0.356667                  False
# 1                  0.000000        0.066667                   True
# 2                  0.576331        0.800000                  False
# 3                  0.665680        0.883333                   True
# 4                  0.673077        0.356667                   True
# 5                  0.414941        0.460815                  False
# 6                  0.665680        0.356667                  False
# 7                  0.673077        1.000000                  False
# 8                  0.876849        0.356667                  False
# 9                  0.876849        0.460815                   True
# 10                 0.424926        1.000000                  False
# 11                 0.665680        0.626667                  False
# 12                 0.876849        0.016667                  False
# ...

# %%
pd.get_dummies(df,columns=["Energy_Source"]).astype(int)
# Out:
#     Energy_Consumption(MWh)  Cost(Million$)  Energy_Source_Biomass  \
# 0                         0               0                      0
# 1                         0               0                      1
# 2                         0               0                      0
# 3                         0               0                      1
# 4                         0               0                      1
# 5                         0               0                      0
# 6                         0               0                      0
# 7                         0               1                      0
# 8                         0               0                      0
# 9                         0               0                      1
# 10                        0               1                      0
# 11                        0               0                      0
# 12                        0               0                      0
# ...
