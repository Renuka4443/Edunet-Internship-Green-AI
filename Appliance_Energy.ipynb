# %%
import pandas as pd
import numpy as np

# %%
energy=pd.read_csv("appliance_energy.csv")
energy
# Out:
#     Temperature (°C)  Energy Consumption (kWh)
# 0          22.490802                  2.292604
# 1          34.014286                  3.251925
# 2          29.639879                  3.009868
# 3          26.973170                  1.703533
# 4          18.120373                  1.702201
# ..               ...                       ...
# 95         24.875912                  2.079686
# 96         25.454657                  2.506915
# 97         23.550820                  2.525658
# 98         15.508383                  1.689184
# 99         17.157829                  2.129374
#
# [100 rows x 2 columns]

# %%
energy.isna().sum()
# Out:
# Temperature (°C)            0
# Energy Consumption (kWh)    0
# dtype: int64

# %%
energy.describe()
# Out:
#        Temperature (°C)  Energy Consumption (kWh)
# count        100.000000                100.000000
# mean          24.403615                  2.439821
# std            5.949788                  0.693527
# min           15.110442                  0.978107
# 25%           18.864015                  1.908640
# 50%           24.282849                  2.364121
# 75%           29.604062                  2.931199
# max           34.737739                  4.159094

# %%
X=salary[["Temperature (°C)"]]
y=salary["Energy Consumption (kWh)"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([1.67123815, 3.13983236, 2.923267  , 2.72942144, 2.01613415,
#        2.33656307, 2.07507916, 3.08378603, 1.59531669, 2.22064637,
#        2.32206301, 2.63229339, 2.99961742, 3.23533639, 1.77023618,
#        1.83458677, 2.9215455 , 1.68976419, 3.02961795, 1.86021346,
#        3.1876158 , 3.12637971, 1.91171185, 1.61970412, 3.30247306,
#        1.8829691 , 1.77455395, 2.48245688, 2.80989466, 1.56870615])

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_pred,y_test)
r2
# Out:
# 0.5491028585149704

# %%
jb.dump(regressor,"Energy_Consumption_predictor.pkl")
# Out:
# ['Energy_Consumption_predictor.pkl']

# %%
mymodel=jb.load("Energy_Consumption_predictor.pkl")

# %%
temp=float(input("Enter the tempertaure in degree celsius(°C) to know the energy consumption:"))
new_data=np.array([[temp]])
predict=mymodel.predict(new_data)
print(f"The predicted energy consumption for temperature {temp}°C is {predict[0]:.6f} kWh")
# Out:
# Enter the tempertaure in degree celsius(°C) to know the energy consumption: 34
# The predicted energy consumption for temperature 34.0°C is 3.237305 kWh
# C:\Users\RENUKA\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
